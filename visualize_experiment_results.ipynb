# %%
import pandas as pd

df = pd.read_pickle(r'C:\Users\rcpsi\source\repos\FeatureGeneration\results_continuous_fetures_2023_02_07.pkl')

# %%
for d in df:
    if d[0] == 1:
        print(d)
# Out:
# [1, 'XGBRegressor(ba', 1, 0.15, 0.9225773424481633, 0.03703862341024692, 0.9225773424481633, 0.03703862341024692]
# [1, 'XGBRegressor(ba', 1, 0.2, 0.9225773424481633, 0.03703862341024692, 0.9244548934685712, 0.03733508029651514]
# [1, 'XGBRegressor(ba', 1, 0.25, 0.9225773424481633, 0.03703862341024692, 0.9324482432504299, 0.047629993767731756]
# [1, 'XGBRegressor(ba', 2, 0.15, 0.9225773424481633, 0.03703862341024692, 0.920626987838234, 0.036784137036138]
# [1, 'XGBRegressor(ba', 2, 0.2, 0.9225773424481633, 0.03703862341024692, 0.9264900461050191, 0.038456075761052366]
# [1, 'XGBRegressor(ba', 2, 0.25, 0.9225773424481633, 0.03703862341024692, 0.9269550572843158, 0.03704511079734953]
# [1, 'XGBRegressor(ba', 5, 0.15, 0.9225773424481633, 0.03703862341024692, 0.930477126598641, 0.040385750183354815]
# [1, 'XGBRegressor(ba', 5, 0.2, 0.9225773424481633, 0.03703862341024692, 0.9317646600422469, 0.03362177656806019]
# ...
